# %% [markdown]
# <a href="https://colab.research.google.com/github/anu82sharma12/Open-Source-Intelligence-Tech-Ecosystems-/blob/main/Cognitive_Stack_Framework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
modules = ["Perception","Reasoning","Decision"]
baseline_time = [30,50,40]
optimized = [t*0.72 for t in baseline_time]
print(f"Inference improvement: {round((1 - sum(optimized)/sum(baseline_time))*100,1)}%")
# Out:
# Inference improvement: 28.0%

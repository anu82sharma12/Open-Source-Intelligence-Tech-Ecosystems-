# %% [markdown]
# <a href="https://colab.research.google.com/github/anu82sharma12/Open-Source-Intelligence-Tech-Ecosystems-/blob/main/Edge_Inference_Starter_Kit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
model_size = 100
compressed = model_size * 0.6
accuracy_loss = 1
print(f"Model compressed to {compressed}% size with <{accuracy_loss}% loss.")
# Out:
# Model compressed to 60.0% size with <1% loss.
